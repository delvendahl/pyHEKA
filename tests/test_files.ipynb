# %%
import sys

# Add the parent directory to sys.path so we can import HekaReader
sys.path.append("../")

from pathlib import Path

from HekaReader import Bundle

# %%
folder_path = Path(r"/Users/igor/Projects/Data analysis/HEKA DAT file import/HEKA DAT file examples")

for file in folder_path.iterdir():
    if file.is_file():
        with Bundle(file) as bundle:
            bundle.summary()
        print()
# Out:
# File: /Users/igor/Projects/Data analysis/HEKA DAT file import/HEKA DAT file examples/Username_2022-11-25_001.dat
# Format: v1000
# Version: v2x90.5, 09-Apr-2019
# Time: 2022-11-25 12:44:37.923000
# ----------------------------------------
# PGF Protocols: cc0, current_steps, stairs2, VC-80
# ----------------------------------------
# Data Content:
# Group 1: E-334 (6 series)
# Group 2: E-335 (5 series)
# Group 3: E-336 (6 series)
# Group 4: E-337 (5 series)
# Group 5: E-338 (5 series)
# Group 6: E-339 (5 series)
# Group 7: E-340 (6 series)
# Group 8: E-341 (6 series)
# Group 9: E-342 (5 series)
# Group 10: E-343 (7 series)
# Group 11: E-344 (6 series)
# Group 12: E-345 (5 series)
# ----------------------------------------
#
# File: /Users/igor/Projects/Data analysis/HEKA DAT file import/HEKA DAT file examples/A_2026-05-19_001.dat
# Format: v1000
# Version: v2x90.5, 09-Apr-2019
# Time: 2026-05-19 09:37:04.368999
# ----------------------------------------
# PGF Protocols: conti_vc, iv_vc, pulse_leak_vc, conti_cc, step_cc
# ----------------------------------------
# Data Content:
# Group 1: E-1 (5 series)
# ----------------------------------------
#
# File: /Users/igor/Projects/Data analysis/HEKA DAT file import/HEKA DAT file examples/20022026a5.dat
# Format: v2000
# Version: 1.6.0 [Build 1066]
# Time: 2026-02-20 11:45:35.732000
# ----------------------------------------
# PGF Protocols: Trigger, ATPase-fluo
# ----------------------------------------
# Data Content:
# Group 1: Exp-1 (9 series)
# ----------------------------------------
#
# File: /Users/igor/Projects/Data analysis/HEKA DAT file import/HEKA DAT file examples/01_25-03-13.dat
# Format: v9
# Version: v2.11, 14-Mar-2006
# Time: 2025-03-13 08:45:34.562410
# ----------------------------------------
# PGF Protocols: IV_2.5s_-140mV
# ----------------------------------------
# Data Content:
# Group 1: E-103 (13 series)
# ----------------------------------------
