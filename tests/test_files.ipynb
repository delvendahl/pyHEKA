# %%
from pathlib import Path

from pyheka import Bundle

# %%
with Bundle(Path("2026-05-19_001.dat")) as bundle:
    bundle.summary(detailed=True)
# Out:
# File: 2026-05-19_001.dat
# Size: 136.09 KB
# Format: v1000
# Version: v2x90.5, 09-Apr-2019
# Time: 2026-05-19 09:37:04.368999
# ----------------------------------------
# PGF Protocols: conti_vc, iv_vc, pulse_leak_vc, conti_cc, step_cc
# ----------------------------------------
# Data Content:
# Group 1: E-1 (5 series)
#     Series 1: conti_vc (Mode: WholeCell, 2 sweeps)
#     Series 2: iv_vc (Mode: WholeCell, 11 sweeps)
#     Series 3: pulse_leak_vc (Mode: WholeCell, 1 sweeps)
#     Series 4: conti_cc (Mode: CClamp, 2 sweeps)
#     Series 5: step_cc (Mode: CClamp, 3 sweeps)
# ----------------------------------------
